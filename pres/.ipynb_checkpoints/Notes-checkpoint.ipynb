# %% [markdown]
# # Scenario
# - Search speed tested on:
#    - std::map
#    - std::unordered_map with
#       - dynamically selected buckets
#       - ~100 buckets
#       - ~1000 buckets
#       - ~5000 buckets
#       - ~10000 buckets
#       - ~20000 buckets
#       - ~40000 buckets
#       - ~70000 buckets
#    - simple binary tree
#    - contiguous binary tree
#
#
# # Test cases
# - 1000 nodes
# - 10000 nodes
# - 100000 nodes
# - 1000000 nodes
# - 10000000 nodes
#
# # Units
# - search/second
# - instructions/search
# - cpu cycles/search
# - branches/search
# - branch misses/search
#
# # Hardware
# - CPU
#    - clock speed: 2GHz
#    - cores/logical untis: 4/8
#    - Cache: 320K/5M/8M
# - Memory:
#    - 8GB
#
# # Software
# - Operating System: Ubuntu (WSL)
# - Language: C++ (complied w/ gcc)
# - Libraries (C++ standard library, nanobench)
